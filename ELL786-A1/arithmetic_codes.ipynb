# %%
import random
import numpy as np
import math

#reading text file
#txt_file = open("new.txt", "r")
#data = txt_file.read()
#txt_file.close()
data = "ramneek ramneek ramneek gfg"

#length of input string
n  = len(data)

#string of unique character
s=""
for i in range(n):
    if(s.find(data[i])==-1):
        s+=data[i]
print(s)

#number of unique characters 
l = len(s)

#x stores occurence of each character
x = np.zeros(l)
#y stores probability of each character
y = np.zeros(l)

for i in range(l):
    #c in number of occurence of each character
    c = data.count(s[i])
    x[i] = c
    y[i] = c/n

#calculate sum upto to some index of array
def sum_upto_index(a,i):
    s = 0
    for j in range(i+1):
        s+=a[j]
    return s

#cp stores the cumulative summation of 'p' from '1' till last value of 'p
cp = np.zeros(l)
for i in range(l):
    cp[i] = sum_upto_index(y,i)
print(y)    
print(cp)    
modified_cp = np.zeros(l+1)
for i in range(l):
    modified_cp[i+1] = cp[i]

#inter stores the intervals    
inter = np.zeros((l,2))
for i in range(l):
    inter[i][0] = modified_cp[i]
    inter[i][1] = cp[i]    


#encoding
l1 = 0
h1 = 1
for i in range(n):
    for j in range(l):
    
        #if character from data matches with the string s
        if(data[i]==s[j]):
            p = j
            j+=1
            r = h1-l1
            h1 = l1 + r*(inter[p][1])
            l1 = l1 + r*(inter[p][0])
            i+=1
            break


tag = (l1+h1)/2
print(tag)


def prof_seq(s,y):
    p=1.0
    for c in s:
        prob *= prob_model[alphabet.index(c)]
    return p

# 0<=tag<1
def encode_tag(tag, length):
    code = ""
    i = 0
    while tag != 0.0 and i < length:
        tag *= 2
        code += str(math.floor(tag))
        tag = tag - math.floor(tag)
        i += 1
    return code


def generate_binary_code(x, alphabet, prob_model):
    prob = prob_seq(x, alphabet, prob_model)
    length = math.ceil(math.log(1 / prob, 2)) + 1
    return encode_tag(tag, length)



#decoding

decoded_string = ""

for i in range(n):
    for j in range(l):
        
        #if l1 value falls within the range
        if (l1>inter[j][0] and l1<inter[j][1]):
            
            p1 = j
            l1 = (l1 - inter[p1][0])/(y[j])
            decoded_string+=s[p1]
            break

print(decoded_string)
# Out:
# ramnek gf
# [0.11111111 0.11111111 0.11111111 0.11111111 0.22222222 0.11111111
#  0.11111111 0.07407407 0.03703704]
# [0.11111111 0.22222222 0.33333333 0.44444444 0.66666667 0.77777778
#  0.88888889 0.96296296 1.        ]
# 0.015634874083428937
# ramneek ramneek ramm gkg ee
